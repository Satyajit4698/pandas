# %%
import pandas as pd

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip")
data
# Out:
#              trip_completed_at trip_status ride_hailing_app  \
# 0       May 11, 2015 at 6:55PM   Completed             Uber
# 1       May 11, 2015 at 8:12PM   Completed             Uber
# 2      May 13, 2015 at 11:38AM   Completed             Uber
# 3       May 16, 2015 at 1:44AM   Completed             Uber
# 4       May 16, 2015 at 3:18AM   Completed             Uber
# ..                         ...         ...              ...
# 673  April 23, 2018 at 12:11PM   Completed             Uber
# 674  April 24, 2018 at 02:58PM   Completed             Uber
# 675  April 26, 2018 at 03:57PM   Completed             Uber
# 676  April 26, 2018 at 05:00PM   Completed             Uber
# 677  April 27, 2018 at 03:05PM   Completed             Uber
#
#                              trip_uid                        driver_uid  \
# 0    ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1    518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# ...

# %%
data.describe(include="all")
# Out:
#                    trip_completed_at trip_status ride_hailing_app  \
# count                            678         678              678
# unique                           678           2                2
# top     November 27, 2017 at 05:58PM   Completed             Uber
# freq                               1         668              642
# mean                             NaN         NaN              NaN
# std                              NaN         NaN              NaN
# min                              NaN         NaN              NaN
# 25%                              NaN         NaN              NaN
# 50%                              NaN         NaN              NaN
# 75%                              NaN         NaN              NaN
# max                              NaN         NaN              NaN
#
#                                 trip_uid                        driver_uid  \
# count                                678                               678
# ...

# %%
data.shape
# Out:
# (678, 45)

# %%
data.empty
# Out:
# False

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",nrows=4)
data
# Out:
#          trip_completed_at trip_status ride_hailing_app  \
# 0   May 11, 2015 at 6:55PM   Completed             Uber
# 1   May 11, 2015 at 8:12PM   Completed             Uber
# 2  May 13, 2015 at 11:38AM   Completed             Uber
# 3   May 16, 2015 at 1:44AM   Completed             Uber
#
#                            trip_uid                        driver_uid  \
# 0  ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1  518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# 2  6e460cc8a12c3c6568d0d4a67ac58393  cb249a2bd807ca78697b4ed0348c37da
# 3  49613a86a04e6c15d72b51d1a2935d81  d3f73f8151c2e8c34b541f961db7f5fa
#
#                           rider_uid  customer      trip_start_time  \
# 0  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan  2015-05-11 17:26:00
# 1  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan  2015-05-11 18:46:00
# 2  3ffa4a71a5aa791a8bc3409f5b15b936  stantyan  2015-05-13 09:15:00
# ...

# %%
data.columns
# Out:
# Index(['trip_completed_at', 'trip_status', 'ride_hailing_app', 'trip_uid',
#        'driver_uid', 'rider_uid', 'customer', 'trip_start_time',
#        'trip_end_time', 'trip_time', 'total_time', 'wait_time', 'trip_type',
#        'surge_multiplier', 'vehicle_make_model', 'vehicle_license_plate',
#        'driver_name_en', 'vehicle_make', 'vehicle_model', 'driver_gender',
#        'driver_photo_url', 'driver_phone_number', 'pickup_lat', 'pickup_long',
#        'dropoff_lat', 'dropoff_long', 'trip_map_image_url',
#        'trip_path_image_url', 'city', 'country', 'trip_start_address',
#        'trip_end_address', 'rub_usd_exchange_rate', 'price_rub', 'price_usd',
#        'distance_kms', 'temperature_time', 'temperature_value', 'feels_like',
#        'humidity', 'wind_speed', 'cloudness', 'weather_main', 'weather_desc',
#        'precipitation'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",names=[4])
data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            4
# ...

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",usecols=[2])
data
# Out:
#     ride_hailing_app
# 0               Uber
# 1               Uber
# 2               Uber
# 3               Uber
# 4               Uber
# ..               ...
# 673             Uber
# 674             Uber
# 675             Uber
# 676             Uber
# 677             Uber
#
# [678 rows x 1 columns]

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",skiprows=4)
data
# Out:
#         May 16, 2015 at 1:44AM  Completed  Uber  \
# 0       May 16, 2015 at 3:18AM  Completed  Uber
# 1      May 18, 2015 at 11:06AM  Completed  Uber
# 2      May 18, 2015 at 11:08PM  Completed  Uber
# 3       May 19, 2015 at 9:10AM  Completed  Uber
# 4      May 19, 2015 at 12:37PM  Completed  Uber
# ..                         ...        ...   ...
# 669  April 23, 2018 at 12:11PM  Completed  Uber
# 670  April 24, 2018 at 02:58PM  Completed  Uber
# 671  April 26, 2018 at 03:57PM  Completed  Uber
# 672  April 26, 2018 at 05:00PM  Completed  Uber
# 673  April 27, 2018 at 03:05PM  Completed  Uber
#
#      49613a86a04e6c15d72b51d1a2935d81  d3f73f8151c2e8c34b541f961db7f5fa  \
# 0    9896148fdecdb4c5d977a8691510bdb6  1287d21e6455ee40d4861f6b91c680f4
# 1    5c0312a92ff104197d799c42ae67542f  fc6b1516376f15c97e508d904505d27a
# 2    4ad2e954813b53afeb73ce659ac3376c  1b926e88a8477f7b5d1fad298e00fb11
# 3    1e3935b05addc654d65e72b8da96fd43  439ae2cf8ae38bc24b2f8dbc3f0b987d
# ...

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",index_col='trip_completed_at')
data
# Out:
#                           trip_status ride_hailing_app  \
# trip_completed_at
# May 11, 2015 at 6:55PM      Completed             Uber
# May 11, 2015 at 8:12PM      Completed             Uber
# May 13, 2015 at 11:38AM     Completed             Uber
# May 16, 2015 at 1:44AM      Completed             Uber
# May 16, 2015 at 3:18AM      Completed             Uber
# ...                               ...              ...
# April 23, 2018 at 12:11PM   Completed             Uber
# April 24, 2018 at 02:58PM   Completed             Uber
# April 26, 2018 at 03:57PM   Completed             Uber
# April 26, 2018 at 05:00PM   Completed             Uber
# April 27, 2018 at 03:05PM   Completed             Uber
#
#                                                    trip_uid  \
# trip_completed_at
# May 11, 2015 at 6:55PM     ee89076fd9da9bddf5f096b0ca42f8d5
# May 11, 2015 at 8:12PM     518be51d403944a03c47e8d1f2c87311
# May 13, 2015 at 11:38AM    6e460cc8a12c3c6568d0d4a67ac58393
# ...

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",header=1)
data
# Out:
#         May 11, 2015 at 6:55PM  Completed  Uber  \
# 0       May 11, 2015 at 8:12PM  Completed  Uber
# 1      May 13, 2015 at 11:38AM  Completed  Uber
# 2       May 16, 2015 at 1:44AM  Completed  Uber
# 3       May 16, 2015 at 3:18AM  Completed  Uber
# 4      May 18, 2015 at 11:06AM  Completed  Uber
# ..                         ...        ...   ...
# 672  April 23, 2018 at 12:11PM  Completed  Uber
# 673  April 24, 2018 at 02:58PM  Completed  Uber
# 674  April 26, 2018 at 03:57PM  Completed  Uber
# 675  April 26, 2018 at 05:00PM  Completed  Uber
# 676  April 27, 2018 at 03:05PM  Completed  Uber
#
#      ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59  \
# 0    518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# 1    6e460cc8a12c3c6568d0d4a67ac58393  cb249a2bd807ca78697b4ed0348c37da
# 2    49613a86a04e6c15d72b51d1a2935d81  d3f73f8151c2e8c34b541f961db7f5fa
# 3    9896148fdecdb4c5d977a8691510bdb6  1287d21e6455ee40d4861f6b91c680f4
# ...

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",header=2)
data
# Out:
#         May 11, 2015 at 8:12PM  Completed  Uber  \
# 0      May 13, 2015 at 11:38AM  Completed  Uber
# 1       May 16, 2015 at 1:44AM  Completed  Uber
# 2       May 16, 2015 at 3:18AM  Completed  Uber
# 3      May 18, 2015 at 11:06AM  Completed  Uber
# 4      May 18, 2015 at 11:08PM  Completed  Uber
# ..                         ...        ...   ...
# 671  April 23, 2018 at 12:11PM  Completed  Uber
# 672  April 24, 2018 at 02:58PM  Completed  Uber
# 673  April 26, 2018 at 03:57PM  Completed  Uber
# 674  April 26, 2018 at 05:00PM  Completed  Uber
# 675  April 27, 2018 at 03:05PM  Completed  Uber
#
#      518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54  \
# 0    6e460cc8a12c3c6568d0d4a67ac58393  cb249a2bd807ca78697b4ed0348c37da
# 1    49613a86a04e6c15d72b51d1a2935d81  d3f73f8151c2e8c34b541f961db7f5fa
# 2    9896148fdecdb4c5d977a8691510bdb6  1287d21e6455ee40d4861f6b91c680f4
# 3    5c0312a92ff104197d799c42ae67542f  fc6b1516376f15c97e508d904505d27a
# ...

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",header=None)
data
# Out:
#                             0            1                 2   \
# 0            trip_completed_at  trip_status  ride_hailing_app
# 1       May 11, 2015 at 6:55PM    Completed              Uber
# 2       May 11, 2015 at 8:12PM    Completed              Uber
# 3      May 13, 2015 at 11:38AM    Completed              Uber
# 4       May 16, 2015 at 1:44AM    Completed              Uber
# ..                         ...          ...               ...
# 674  April 23, 2018 at 12:11PM    Completed              Uber
# 675  April 24, 2018 at 02:58PM    Completed              Uber
# 676  April 26, 2018 at 03:57PM    Completed              Uber
# 677  April 26, 2018 at 05:00PM    Completed              Uber
# 678  April 27, 2018 at 03:05PM    Completed              Uber
#
#                                    3                                 4   \
# 0                            trip_uid                        driver_uid
# 1    ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# ...

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",header=None,prefix='col')
data
# Out:
#                           col0         col1              col2  \
# 0            trip_completed_at  trip_status  ride_hailing_app
# 1       May 11, 2015 at 6:55PM    Completed              Uber
# 2       May 11, 2015 at 8:12PM    Completed              Uber
# 3      May 13, 2015 at 11:38AM    Completed              Uber
# 4       May 16, 2015 at 1:44AM    Completed              Uber
# ..                         ...          ...               ...
# 674  April 23, 2018 at 12:11PM    Completed              Uber
# 675  April 24, 2018 at 02:58PM    Completed              Uber
# 676  April 26, 2018 at 03:57PM    Completed              Uber
# 677  April 26, 2018 at 05:00PM    Completed              Uber
# 678  April 27, 2018 at 03:05PM    Completed              Uber
#
#                                  col3                              col4  \
# 0                            trip_uid                        driver_uid
# 1    ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# ...

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",names=['a','b','c','ag','by','cy'])
data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       a  \
# ...

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",dtype={'feels_like':'float64'})
data
# Out:
#              trip_completed_at trip_status ride_hailing_app  \
# 0       May 11, 2015 at 6:55PM   Completed             Uber
# 1       May 11, 2015 at 8:12PM   Completed             Uber
# 2      May 13, 2015 at 11:38AM   Completed             Uber
# 3       May 16, 2015 at 1:44AM   Completed             Uber
# 4       May 16, 2015 at 3:18AM   Completed             Uber
# ..                         ...         ...              ...
# 673  April 23, 2018 at 12:11PM   Completed             Uber
# 674  April 24, 2018 at 02:58PM   Completed             Uber
# 675  April 26, 2018 at 03:57PM   Completed             Uber
# 676  April 26, 2018 at 05:00PM   Completed             Uber
# 677  April 27, 2018 at 03:05PM   Completed             Uber
#
#                              trip_uid                        driver_uid  \
# 0    ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1    518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# ...

# %%
data=pd.read_csv("C:/Users/routs/Downloads/uber-rides.zip",true_values=[''])
data
# Out:
#              trip_completed_at trip_status ride_hailing_app  \
# 0       May 11, 2015 at 6:55PM   Completed             Uber
# 1       May 11, 2015 at 8:12PM   Completed             Uber
# 2      May 13, 2015 at 11:38AM   Completed             Uber
# 3       May 16, 2015 at 1:44AM   Completed             Uber
# 4       May 16, 2015 at 3:18AM   Completed             Uber
# ..                         ...         ...              ...
# 673  April 23, 2018 at 12:11PM   Completed             Uber
# 674  April 24, 2018 at 02:58PM   Completed             Uber
# 675  April 26, 2018 at 03:57PM   Completed             Uber
# 676  April 26, 2018 at 05:00PM   Completed             Uber
# 677  April 27, 2018 at 03:05PM   Completed             Uber
#
#                              trip_uid                        driver_uid  \
# 0    ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1    518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# ...

# %%
data.isnull()
# Out:
#      trip_completed_at  trip_status  ride_hailing_app  trip_uid  driver_uid  \
# 0                False        False             False     False       False
# 1                False        False             False     False       False
# 2                False        False             False     False       False
# 3                False        False             False     False       False
# 4                False        False             False     False       False
# ..                 ...          ...               ...       ...         ...
# 673              False        False             False     False       False
# 674              False        False             False     False       False
# 675              False        False             False     False       False
# 676              False        False             False     False       False
# 677              False        False             False     False       False
#
# ...

# %%
data.isnull().sum()
# Out:
# trip_completed_at         0
# trip_status               0
# ride_hailing_app          0
# trip_uid                  0
# driver_uid                0
# rider_uid                 0
# customer                  0
# trip_start_time           0
# trip_end_time             0
# trip_time                 0
# total_time                0
# wait_time                 0
# trip_type                 0
# surge_multiplier         35
# vehicle_make_model        0
# vehicle_license_plate     0
# driver_name_en            0
# vehicle_make              0
# vehicle_model             0
# driver_gender             0
# driver_photo_url          0
# driver_phone_number       0
# pickup_lat                0
# pickup_long               0
# dropoff_lat               0
# dropoff_long              0
# trip_map_image_url        0
# trip_path_image_url       0
# city                      0
# country                   0
# trip_start_address        0
# trip_end_address          0
# rub_usd_exchange_rate     0
# ...

# %%
data.isnull().sum().sum()
# Out:
# 35

# %%
data.notnull()
# Out:
#      trip_completed_at  trip_status  ride_hailing_app  trip_uid  driver_uid  \
# 0                 True         True              True      True        True
# 1                 True         True              True      True        True
# 2                 True         True              True      True        True
# 3                 True         True              True      True        True
# 4                 True         True              True      True        True
# ..                 ...          ...               ...       ...         ...
# 673               True         True              True      True        True
# 674               True         True              True      True        True
# 675               True         True              True      True        True
# 676               True         True              True      True        True
# 677               True         True              True      True        True
#
# ...

# %%
data.notnull().sum()
# Out:
# trip_completed_at        678
# trip_status              678
# ride_hailing_app         678
# trip_uid                 678
# driver_uid               678
# rider_uid                678
# customer                 678
# trip_start_time          678
# trip_end_time            678
# trip_time                678
# total_time               678
# wait_time                678
# trip_type                678
# surge_multiplier         643
# vehicle_make_model       678
# vehicle_license_plate    678
# driver_name_en           678
# vehicle_make             678
# vehicle_model            678
# driver_gender            678
# driver_photo_url         678
# driver_phone_number      678
# pickup_lat               678
# pickup_long              678
# dropoff_lat              678
# dropoff_long             678
# trip_map_image_url       678
# trip_path_image_url      678
# city                     678
# country                  678
# trip_start_address       678
# trip_end_address         678
# ...

# %%
data.notnull().sum().sum()
# Out:
# 30475

# %% [markdown]
# # series

# %%
import numpy as np

# %%
ser=pd.Series([1,2,3,4,5,np.nan,6,7,8,np.NAN])
ser
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    NaN
# 6    6.0
# 7    7.0
# 8    8.0
# 9    NaN
# dtype: float64

# %%
ser.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9     True
# dtype: bool

# %%
ser.isnull().sum()
# Out:
# 2

# %%
ser.dropna()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 6    6.0
# 7    7.0
# 8    8.0
# dtype: float64

# %%
ser.dropna(axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-e171bd4974f2> in <module>
# ----> 1 ser.dropna(axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in dropna(self, axis, inplace, **kwargs)
#    4777             )
#    4778         # Validate the axis parameter
# -> 4779         self._get_axis_number(axis or 0)
#    4780
#    4781         if self._can_hold_na:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     409             except KeyError:
#     410                 pass
# --> 411         raise ValueError("No axis named {0} for object type {1}".format(axis, cls))
#     412
#     413     @classmethod
#
# ValueError: No axis named 1 for object type <class 'pandas.core.series.Series'>

# %%
ser.dropna(how='any')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 6    6.0
# 7    7.0
# 8    8.0
# dtype: float64

# %%
ser.dropna(axis=1,how='any')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-d865aea1452c> in <module>
# ----> 1 ser.dropna(axis=1,how='any')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in dropna(self, axis, inplace, **kwargs)
#    4777             )
#    4778         # Validate the axis parameter
# -> 4779         self._get_axis_number(axis or 0)
#    4780
#    4781         if self._can_hold_na:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     409             except KeyError:
#     410                 pass
# --> 411         raise ValueError("No axis named {0} for object type {1}".format(axis, cls))
#     412
#     413     @classmethod
#
# ValueError: No axis named 1 for object type <class 'pandas.core.series.Series'>

# %%
data.dropna(axis=1,how='any')
# Out:
#              trip_completed_at trip_status ride_hailing_app  \
# 0       May 11, 2015 at 6:55PM   Completed             Uber
# 1       May 11, 2015 at 8:12PM   Completed             Uber
# 2      May 13, 2015 at 11:38AM   Completed             Uber
# 3       May 16, 2015 at 1:44AM   Completed             Uber
# 4       May 16, 2015 at 3:18AM   Completed             Uber
# ..                         ...         ...              ...
# 673  April 23, 2018 at 12:11PM   Completed             Uber
# 674  April 24, 2018 at 02:58PM   Completed             Uber
# 675  April 26, 2018 at 03:57PM   Completed             Uber
# 676  April 26, 2018 at 05:00PM   Completed             Uber
# 677  April 27, 2018 at 03:05PM   Completed             Uber
#
#                              trip_uid                        driver_uid  \
# 0    ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1    518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# ...

# %%
ser.dropna(how='all')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 6    6.0
# 7    7.0
# 8    8.0
# dtype: float64

# %%
data.dropna(thresh=2)
# Out:
#              trip_completed_at trip_status ride_hailing_app  \
# 0       May 11, 2015 at 6:55PM   Completed             Uber
# 1       May 11, 2015 at 8:12PM   Completed             Uber
# 2      May 13, 2015 at 11:38AM   Completed             Uber
# 3       May 16, 2015 at 1:44AM   Completed             Uber
# 4       May 16, 2015 at 3:18AM   Completed             Uber
# ..                         ...         ...              ...
# 673  April 23, 2018 at 12:11PM   Completed             Uber
# 674  April 24, 2018 at 02:58PM   Completed             Uber
# 675  April 26, 2018 at 03:57PM   Completed             Uber
# 676  April 26, 2018 at 05:00PM   Completed             Uber
# 677  April 27, 2018 at 03:05PM   Completed             Uber
#
#                              trip_uid                        driver_uid  \
# 0    ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1    518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# ...

# %%
data.dropna(subset=['surge_multiplier'])
# Out:
#              trip_completed_at trip_status ride_hailing_app  \
# 0       May 11, 2015 at 6:55PM   Completed             Uber
# 1       May 11, 2015 at 8:12PM   Completed             Uber
# 2      May 13, 2015 at 11:38AM   Completed             Uber
# 3       May 16, 2015 at 1:44AM   Completed             Uber
# 4       May 16, 2015 at 3:18AM   Completed             Uber
# ..                         ...         ...              ...
# 673  April 23, 2018 at 12:11PM   Completed             Uber
# 674  April 24, 2018 at 02:58PM   Completed             Uber
# 675  April 26, 2018 at 03:57PM   Completed             Uber
# 676  April 26, 2018 at 05:00PM   Completed             Uber
# 677  April 27, 2018 at 03:05PM   Completed             Uber
#
#                              trip_uid                        driver_uid  \
# 0    ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1    518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# ...

# %%
data.dropna(inplace=True)

# %%
data.fillna(2)
# Out:
#              trip_completed_at trip_status ride_hailing_app  \
# 0       May 11, 2015 at 6:55PM   Completed             Uber
# 1       May 11, 2015 at 8:12PM   Completed             Uber
# 2      May 13, 2015 at 11:38AM   Completed             Uber
# 3       May 16, 2015 at 1:44AM   Completed             Uber
# 4       May 16, 2015 at 3:18AM   Completed             Uber
# ..                         ...         ...              ...
# 673  April 23, 2018 at 12:11PM   Completed             Uber
# 674  April 24, 2018 at 02:58PM   Completed             Uber
# 675  April 26, 2018 at 03:57PM   Completed             Uber
# 676  April 26, 2018 at 05:00PM   Completed             Uber
# 677  April 27, 2018 at 03:05PM   Completed             Uber
#
#                              trip_uid                        driver_uid  \
# 0    ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1    518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# ...

# %%
ser.fillna(0)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    0.0
# 6    6.0
# 7    7.0
# 8    8.0
# 9    0.0
# dtype: float64

# %%
ser.fillna()
